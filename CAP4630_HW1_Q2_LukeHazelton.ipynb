# %% [markdown]
# #Setup

# %%
# Imports
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Define
seed = 42
np.random.seed(seed)

xs1 = 2 * np.random.rand(100, 1)
xs2 = 2 * np.random.rand(100, 1)
ys = 4 + 3 * xs1 + xs2 + np.random.rand(100, 1)

# %% [markdown]
# #Plot

# %%
plt.plot(xs1, ys, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
plt.plot(xs2, ys, "r.")
plt.xlabel("$x_2$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# #Train

# %%
# split the data into training and test sets
# train set
train_xs1 = xs1[:80]
train_xs2 = xs2[:80]
train_ys = ys[:80]
# test set
test_xs1 = xs1[80:]
test_xs2 = xs2[80:]
test_ys = ys[80:]

# %% [markdown]
# #Linear regression

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial value for weight w and bias b
w1 = np.random.randn(1)
w2 = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = w1 * train_xs1[i] + w2 * train_xs2[i] + b
    
    grad_w1 = (y_pred - train_ys[i]) * train_xs1[i]
    grad_w2 = (y_pred - train_ys[i]) * train_xs2[i]
    grad_b = (y_pred - train_ys[i])
    
    w1 -= lr * grad_w1
    w2 -= lr * grad_w2
    b -= lr * grad_b

# %% [markdown]
# #Loss

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * (w1 * test_xs1[i] + w2 * test_xs2[i] + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.07365286])

# %%
pred_ys = w1 * test_xs1 + w2 * test_xs2 + b

# %% [markdown]
# #Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(test_xs1, test_xs2, pred_ys, c='r', marker='o')
ax.scatter(test_xs1, test_xs2, test_ys, c='b', marker='o')

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Y')

plt.show()
